# %% [markdown]
# <center><h1>INTRODUCTION TO DATA VISUALIZATION IN POWER BI</h1></center>

# %% [markdown]
# ***
# <b>Content</b>
# - 1. Introduction to Power BI
# - 2. Data Modelling and Data Expressions in Power BI
# - 3. Advanced Visualizations in Power BI
# - 4. Enhancing Dashboards in Power BI
# - 5. Analytics with Power BI
# - 6. Applications of Power BI
# - 7. Mini Project in Power BI

# %% [markdown]
# ***
#
# <center><h2>1. Introduction to Power BI</h2></center>
#
# ***

# %% [markdown]
# <h3>1a. An Introduction to Power BI</h3>

# %% [markdown]
# Microsoft Power BI is a collection of software services, apps, and connectors that work together to turn your unrelated sources of data into coherent, visually immersive, and interactive insights.
#
# ![image.png](attachment:image.png)
#
# Power BI consists of a Microsoft Windows desktop application called *Power BI Desktop*, an online SaaS (Software as a Service) service called the *Power BI service*, and *mobile Power BI* apps that are available on any device, with native mobile BI apps for Windows, iOS, and Android.
#
# - <b>Power BI Desktop:</b>
#     - Power BI Desktop is the authoring tool of Power BI
#     - It is used by the analysts to access, transform, and model the data, create measures, and build the data visualisations.
#     - This application is free to download and supports Windows operating systems.
# - <b>Power BI Service:</b>
#     - The Power BI Service component (https://app.powerbi.com) is the cloud based central hub of the Power BI solution where users access and interact with their Power BI reports.
#     - Users can create dashboards from their reports and use the self-service functions to edit and create new visualisations.
#     - Users can then share the insights found and collaborate with co-workers on reports and dashboards.
# - <b>Power BI Mobile:</b>
#     - The Mobile component of Power BI allows users to interact with their published reports using their smartphones or tablets via a downloadable app.
#     - It enables access to reports on the fly, anywhere, at any time, and provides personalised data alerts for real time data updates.
#     - Power BI Mobile supports Windows, iOS, and Android devices.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>The Flow of Work in Power BI</b>
#
# A common flow of work in Power BI begins in **Power BI Desktop**, where a report is created. That report is then published to the **Power BI Service** and finally shared, so that users of **Power BI Mobile** apps can consume the information.
#
# It doesn't always happen that way, and that's okay. But we'll use that flow to help you learn the different parts of Power BI and how they complement each other.
# </div>

# %% [markdown]
# <b>The Building Blocks of Power BI</b>
#
# In Microsoft Power BI, there are basic building blocks that make up the reports and dashboards consumed by end users. Think of it similarly to the basic construction materials that can be used to build homes or other structures.
#
# <b>The Basic Building Blocks of Power BI are...</b>
#
# - <b>Visualizations:</b> A visualization (or visual) is a visual representation of data, like a chart, a color-coded map, or other interesting things you can create to represent your data visually. The goal of a visual is to present data in a way that provides context and insights, both of which would probably be difficult to discern from a raw table of numbers or text.
# - <b>Semantic Models or, Datasets:</b> A semantic model is a collection of data that Power BI uses to create its visualizations. You can have a simple semantic model that's based on a single table from a Microsoft Excel workbook. Semantic models can also be a combination of many different sources, which you can filter and combine to provide a unique collection of data (a semantic model) for use in Power BI.
# - <b>Reports:</b> A report is a collection of visualizations on one or more pages. Power BI reports combine related data using many visualizations, on multiple pages if necessary, and let you arrange those visualizations in whatever way best tells your story.
# - <b>Dashboards:</b> A dashboard is a selected group of visuals that provide quick and important insight into the data or story you're trying to present. Dashboards are limited to a single page, and allow users to follow a visual to the underlying report. Users interact with dashboards through the Power BI service or on a mobile device.
# - <b>Tiles:</b> A tile is a single visualization on a dashboard. It's the rectangular box that holds an individual visual. In the following image, you see one tile, which is also surrounded by other tiles.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>In summary:</b>
#
# - **Reports** consist of **visualizations** and **semantic models** created with Power BI Desktop application.
# - **Dashboards** consist of **tiles** from report visualizations created in the online Power BI service.
# </div>

# %% [markdown]
# <h3>1b. Data Management in Power BI with Power Query</h3>
#
# Before you can create reports, you must first extract data from the various data sources. Then, you can use Power Query to help you clean the data, such as renaming columns, replacing values, removing errors, and combining query results. Power Query is also available in Excel. After the data has been cleaned and organized, you're ready to build reports in Power BI. Finally, you'll publish your combined semantic model and reports to Power BI service.

# %% [markdown]
# <b>Getting Data</b>
#
# Power BI Desktop allows you to get data from many types of files. You can find a list of the available options when you use the *Get data* feature in Power BI Desktop.
#
# In Power BI, on the Home tab, select Get data. In the list that displays, select the option that you require, such as Text/CSV or XML. For this example, you'll select Excel.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# **Tip:**
#
# The **Home** tab contains quick access data source options, such as **Excel**, next to the **Get data** button.
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)
#
# In this example, open the Employee Data Excel workbook that is stored on the Desktop (Remember, no files are provided for practice, these are hypothetical steps)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# After the file has connected to Power BI Desktop, the Navigator window opens. This window shows you the data that is available in your data source (the Excel file in this example). You can select a table or entity to preview its contents, to ensure that the correct data is loaded into the Power BI model.
#
# Select the check box(es) of the table(s) that you want to bring in to Power BI. This selection activates the Load and Transform Data buttons as shown in the following image.
#
# ![image.png](attachment:image.png)
#
# Now you can select the Load button to automatically load your data into the Power BI model or select the Transform Data button to launch the Power Query Editor, where you can review and clean your data before loading it into the Power BI model.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# Besides Excel files, Power BI can also connect to many other data sources such as:
#
# - **Files** eg. `.txt`, `.csv`, `.json`, `.xml` files
# - **Databases** eg. SQL databases, Access databases, Amazon Redshift, Snowflake
# - **Azure data sources** eg. Azure SQL database, Azure Analysis Services database
# - **Online Services** eg. Google Analytics, Adobe Analytics, Github
# - **Other data sources** eg. Spark, Hadoop, Python/R Scripts

# %% [markdown]
# <b>Changing the Source File</b>
#
# You might have to change the location of a source file for a data source during development, or if a file storage location changes. To keep your reports up to date, you'll need to update your file connection paths in Power BI.
#
# Power Query provides many ways for you to accomplish this task, so that you can make this type of change when needed.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <b>The Power Query Editor</b>
#
# Power Query Editor in Power BI Desktop allows you to shape (transform) your imported data. You can do things like renaming columns or tables, changing text to numbers, removing rows, setting the first row as headers, and much more. It is important to shape your data to ensure that it meets your needs and is suitable for use in reports.

# %% [markdown]
# To start shaping your data, open Power Query Editor by selecting the Transform data option on the Home tab of Power BI Desktop.
#
# ![image.png](attachment:image.png)
#
# The Power Query user interface has five distinct components.
#
# ![image-4.png](attachment:image-4.png)
#
# 1. **Ribbon:** the ribbon navigation experience, which provides multiple tabs to add transforms, select options for your query, and access different ribbon buttons to complete various tasks.
# 2. **Queries Pane:** a view of all your available queries.
# 3. **Current View:** your main working view, which by default, displays a preview of the data for your query. You can also enable the diagram view along with the data preview view. You can also switch between the schema view and the data preview view while maintaining the diagram view.
# 4. **Query Settings:** a view of the currently selected query with relevant information, such as query name, query steps, and various indicators.
# 5. **Status Bar:** a bar displaying relevant important information about your query, such as execution time, total columns and rows, and processing status. This bar also contains buttons to change your current view.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Further Reading:</b>
#
# [Learn more about the Power Query User Interface from Microsoft](https://learn.microsoft.com/en-us/power-query/power-query-ui)

# %% [markdown]
# Power Query has an incredible number of features that are dedicated to helping you clean and prepare your data for analysis. Here is a non-exhaustive list of ways you can transform your data in Power BI:
#
# - Update the data source
# - Update query properties
# - Keep or discard columns/rows
# - Sort tables
# - Split columns
# - Replace or fill missing values
# - Filter columns
# - Convert headers
# - Change data types of columns

# %% [markdown]
# <h3>1c. Visualizations in Power BI</h3>
#
# <b>Selecting Visualizations</b>
#
# The primary goal of data visualization is to communicate information clearly and effectively to report consumers. That's why selecting the most effective visual type to meet requirements is critical.
#
# Visual selection can be challenging because so many visuals are available to choose from. Here are some tips and guidance to help you meet specific visualization requirements.

# %% [markdown]
# <b>Categorical Visuals</b>
#
# Bar or column charts are good choices when you need to show data across multiple categories. If many category values are available, you should avoid selecting a visual where color is used to split the data, such as a stacked bar chart with a category legend. Instead, use the category dimension on the axis of a bar chart.
#
# ![image-5.png](attachment:image-5.png)
#
# Generally, you should sort categorical charts by value rather than in alphabetical category order. The sort order is determined by what you want to first draw peoples' attention to so that it provides the report consumer with an intuitive visual that is organized to produce a natural flow. However, you should sort by category when an established sequence is in place, such as steps in a process that should be displayed in that order.
#
# Finally, avoid a line chart with a categorical X-axis because the line implies a relationship between elements that might not exist.

# %% [markdown]
# <b>Time Series Visuals</b>
#
# Always use a line or column chart to show values over time. The X-axis should present time, sorted from earliest to latest periods. You can bring the line chart to the next level by adding an analytics option. In this case, it applies a forecast to extend historical sales with projected sales.
#
# If there are missing values, the line chart visual will fill such gaps with a straight line that connects the values of the previous and next periods. In this case, a column chart might be a better visual choice because it will help to avoid the interpretation of a non-existent trend.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# Other Power BI core visuals that you can use for time series data include:
#
# - Stacked column chart
# - Area chart
# - Line and stacked column chart
# - Ribbon chart, which has the added benefit of showing rank changes over time

# %% [markdown]
# <b>Numerical Visuals</b>
#
# Often presented by card visuals, numeric values show high-level callouts that demand immediate attention. They can be powerful in dashboard and analytical reports because they communicate important data quickly.

# %% [markdown]
# <b>Geospatial Visuals</b>
#
# When a semantic model has geospatial information, it can be conveyed by using map visuals. The map visual you choose will depend on the level of granularity that you want to demonstrate. For example, if the granularity is at **city** level, a *map* visual will have better clarity over a *filled map* visual.
#
# ![image-2.png](attachment:image-2.png)
#
# If the granularity is at **state** level, a *filled map* will produce a better result.
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>Note:</b>
#
# Map visuals can occupy considerable space on the report page. Also, geospatial data doesn't always need to be shown in maps. If location isn't highly relevant to the requirements, consider using a categorical visual instead.

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Further Reading:</b>
#
# [Understand every visual in Power BI from Microsoft](https://learn.microsoft.com/en-us/power-bi/visuals/power-bi-visualization-types-for-reports-and-q-and-a)

# %% [markdown]
# <h3>1d. Formatting Visuals in Power BI</h3>
#
# Power BI Desktop gives you a variety of options for customizing how your selected visualizations look, such as the colors and format of the text that they contain.

# %% [markdown]
# <b>Modify Colours in Charts and Visuals</b>
#
# - Power BI gives you a lot of control over how colors are displayed.
# - Select a visual then in the Visualizations pane, click the *Paintbrush* icon.
# - You can enhance a visual by changing its color based on a value, measure, or the elements available depending on the visualization selected

# %% [markdown]
# <b>Enhance Visuals for Analysis (Adding a Reference Line)</b>
# - You can use add further analyses to your visuals
# - Select the *Analytics* pane and expand the required *Reference Line* section
# - You can set the value of a reference line, set its color, and label it.

# %% [markdown]
# <b>Add A Shape or Image</b>
# - You can add text, buttons, shapes and images in reports under the *Insert* tab

# %% [markdown]
# <b>Page Layout and Formatting</b>
# - Use the *Page View* menu to change the size of the report page view
# - USe the *Canvas Settings* options to change the size of the report page itself

# %% [markdown]
# ***
#
# <center><h2>2. Data Modelling and Data Expressions in Power BI</center></h2>
#
# ***

# %% [markdown]
# ### Introduction to Data Modelling - What is it and why is it important

# %% [markdown]
# ***
#
# <center><h2>3. Advanced Visualizations in Power BI</center></h2>
#
# ***

# %% [markdown]
# ***
#
# <center><h2>4. Enhancing Dashboards in Power BI</center></h2>
#
# ***

# %% [markdown]
# ***
#
# <center><h2>5. Data Analysis in Power BI</center></h2>
#
# ***

# %% [markdown]
# ***
#
# <center><h2>6. Applications of Power BI</center></h2>
#
# ***

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# [Images and supplementary notes taken from the full Microsoft Power BI course](https://learn.microsoft.com/en-us/training/modules/get-started-with-power-bi/)
